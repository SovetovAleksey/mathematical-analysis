# %% [markdown]
# <a href="https://colab.research.google.com/github/SovetovAleksey/mathematical-analysis/blob/8_quest/8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Найти $\frac{dz}{dt}$, если $z = z(x;y)$, $x = x(t)$, $y = y(t)$

# %% [markdown]
# $z = x^2 + y^2 + xy$, $x = asint$, $y = acost$
#
# $\frac{\partial{z}}{\partial{x}} = 2x + y$
#
# $\frac{\partial{z}}{\partial{y}} = 2y + x$
#
# Подставим
#
# $\frac{\partial{x}}{\partial{t}} = (asint)' = -acost$
#
# $\frac{\partial{y}}{\partial{t}} = -asint$
#
# $\frac{\partial{z}}{\partial{t}} = \frac{\partial{z}}{\partial{x}} \cdot \frac{\partial{x}}{\partial{t}} + \frac{\partial{z}}{\partial{y}} \cdot \frac{\partial{y}}{\partial{t}} = -(2x + y) \cdot acost - (2y + x) \cdot asint$
#
#
# ---

# %% [markdown]
# $z = x^2y^3u$, $x = t$, $y = t^2$, $u = sint$
#
# $\frac{\partial{z}}{\partial{x}} = 2xy^3u$
#
# $\frac{\partial{z}}{\partial{y}} = 3y^2x^2u$
#
# $\frac{\partial{z}}{\partial{u}} = x^2y^3$
#
# Найдем
#
# $\frac{dx}{dt} = 1$
#
# $\frac{dy}{dt} = 2t$
#
# $\frac{du}{dt} = cost$
#
# Подставим
#
# $\frac{\partial{z}}{\partial{t}} = \frac{\partial{z}}{\partial{x}} \cdot \frac{dx}{dt} + \frac{\partial{z}}{\partial{y}} \cdot \frac{dy}{dt} + \frac{\partial{z}}{\partial{u}} \cdot \frac{du}{dt} = 2xy^3u + 3x^2y^2u \cdot 2t + x^2y^3cost$
#
#
# ---

# %% [markdown]
# 2. Для данных $z = f(x;y)$, $x = x(u;v)$, $y = y(u;v)$ найти $\frac{\partial{z}}{\partial{u}}$, $\frac{\partial{z}}{\partial{v}}$ и $dz$

# %% [markdown]
# $z = x^3 + y^3$, где $x = uv$, $y = \frac{u}{v}$
#
# $\frac{\partial{z}}{\partial{u}} = \frac{\partial{z}}{\partial{x}} \cdot \frac{dx}{du} + \frac{\partial{z}}{\partial{y}} \cdot \frac{dy}{du}$
#
# $\frac{\partial{z}}{\partial{v}} = \frac{\partial{z}}{\partial{x}} \cdot \frac{dx}{dv} + \frac{\partial{z}}{\partial{y}} \cdot \frac{dy}{dv}$
#
# Находим
#
# $\frac{\partial{z}}{\partial{x}} = 3x^2$
#
# $\frac{\partial{z}}{\partial{y}} = 3y^2$
#
# $\frac{\partial{x}}{\partial{u}} = v$
#
# $\frac{\partial{x}}{\partial{v}} = u$
#
# $\frac{\partial{y}}{\partial{u}} = \frac{1}{v}$
#
# $\frac{\partial{y}}{\partial{v}} = -\frac{u}{v^2}$
#
# Откуда
#
# $\frac{\partial{z}}{\partial{u}} = 3x^2v + \frac{3y^2}{v}$
#
# $\frac{\partial{z}}{\partial{v}} = 3x^2u - \frac{3y^2u}{v^2}$
#
# $dz = f_x'dx + f_y'dy = 3x^2dx + 3y^2dy$
#
# ---

# %% [markdown]
# $z = cosxy$, где $x = ue^v$, $y = vlnu$
#
# $\frac{\partial{z}}{\partial{u}} = \frac{\partial{z}}{\partial{x}} \cdot \frac{dx}{du} + \frac{\partial{z}}{\partial{y}} \cdot \frac{dy}{du}$
#
# $\frac{\partial{z}}{\partial{v}} = \frac{\partial{z}}{\partial{x}} \cdot \frac{dx}{dv} + \frac{\partial{z}}{\partial{y}} \cdot \frac{dy}{dv}$
#
# Находим
#
# $\frac{\partial{z}}{\partial{x}} = -sinxy \cdot y$
#
# $\frac{\partial{z}}{\partial{y}} = -sinxy \cdot x$
#
# $\frac{\partial{x}}{\partial{u}} = e^v$
#
# $\frac{\partial{y}}{\partial{u}} = \frac{v}{u}$
#
# $\frac{\partial{x}}{\partial{v}} = u \cdot e^v$
#
# $\frac{\partial{y}}{\partial{v}} = lnu$
#
# Откуда
#
# $\frac{\partial{z}}{\partial{u}} = -sinxy \cdot y \cdot e^v - sinxy \cdot x \cdot \frac{v}{u} = -sinxy(ye^v + \frac{xv}{u})$
#
# $\frac{\partial{z}}{\partial{v}} = -sinxy \cdot y \cdot u \cdot e^v - sinxy \cdot xlnu = -sinxy(y \cdot u \cdot e^v + xlnu)$
#
# $dz = f_x'dx + f_y'dy = (-sinxy \cdot y)dx + (-sinxy \cdot x)dy$
#
#
# ---

# %% [markdown]
# 3. Найти производную $y'(x)$ неявной функции, заданной уравнением

# %% [markdown]
# $xe^{2y} - ylnx = 8$
#
# $(xe^{2y})' = (8 + ylnx)'$
#
# $e^{2y} + x \cdot e^{2y} \cdot 2y' = y'lnx + \frac{y}{x}$
#
# $x \cdot e^{2y} \cdot 2y' - y'lnx = \frac{y}{x} - e^{2y}$
#
# $y'(2x \cdot e^{2y} -lnx) = \frac{y}{x} - e^{2y}$
#
# $$y' = \frac{\frac{y}{x} - e^{2y}}{2x \cdot e^{2y} - lnx}$$
#
#
# ---

# %% [markdown]
# 4. Составить уравнение касательной прямой и нормали к кривой $y = y(x)$, заданной уравнением $F(x,y) = 0$ в точке $M_0(x_0;y_0)$: $x^3y - y^3x = 6$, $M_0(2;1)$

# %% [markdown]
# Уравнение касательной:
#
# $y - f(x_0) = f'(x_0)(x - x_0)$
#
# $x_0 = 2$, $f(x_0) = 1$
#
# Найдем
#
# $f'(x_0) = f'(2)$
#
# Найдем производную функции, заданной неявно
#
# $(x^3y - y^3x)'=(6)'$
#
# $3x^2y + x^3y' - 3y^2y'x - y^3 = 0$
#
# $x^3y' - 3y^2y'x = y^3 - 3x^2y$
#
# $y'(x^3 - 3y^2x) = y^3 - 3x^2y$
#
# $$y' = \frac{y^3 - 3x^2y}{x^3 - 3y^2x}$$
#
# Тогда
#
# $f'(x_0) = \frac{1^3 - 3\cdot 2^2 \cdot 1}{2^3 - 3 \cdot 1^2 \cdot 2} = -\frac{11}{2}$
#
# $y - f(x_0) = f'(x_0)(x-x_0)$
#
# $y - 1 = -\frac{11}{2}(x-2)$
#
# $k: 11x + 2y - 24 = 0$
#
# Составим уравнение к нормали
#
# $y - f(x_0) = -\frac{1}{f'(x_0)}(x - x_0)$
#
# $y - 1 = -\frac{1}{-\frac{11}{2}}(x - 2)$
#
# $n: 2x -11y + 7 = 0$
#
#
# ---

# %% [markdown]
# 5. Для данных функций найти требуемую частную производную или дифференциал

# %% [markdown]
# $z = sinx \cdot siny$, $d^2z$
#
# $d^2z = z_{xx}'' \cdot dx^2 + 2z_{xy}'' \cdot dxdy + z_{yy}'' \cdot dy^2$
#
# $z_x' = siny \cdot cosx$
#
# $z_{xx}'' = -sinx \cdot siny$
#
# $z_y' = sinx \cdot cosy$
#
# $z_{yy}'' = -siny \cdot sinx$
#
# $z_{xy}'' = cosy \cdot cosx$
#
# Подставим
#
# $d^2z = -sinx \cdot siny \cdot dx^2 + 2cosy \cdot cosx \cdot dxdy - siny \cdot sinx \cdot dy^2$
#
#
# ---

# %% [markdown]
# $z = xy + sin(x+y)$, $\frac{\partial^2{z}}{\partial{x^2}}$
#
# $\frac{\partial^2{z}}{\partial{x^2}} = z_{xx}''$
#
# $z_x' = y + cos(x+y)$
#
# $z_{xx}'' = -sin(x+y)$
#
#
# ---

# %% [markdown]
# $z = arctg\frac{x+y}{1 - xy}$, $\frac{\partial^2z}{\partial{x}\partial{y}}$
#
# $z_x' = \frac{\partial{z}}{\partial{x}} = \frac{1}{1 + \left(\frac{x+y}{1-xy}\right)^2} \cdot \frac{(x + y)'(1-xy) - (x+y)(1-xy)'}{(1-xy)^2} = \frac{1 -xy + y(x+y)}{\frac{(1-xy)^2 + (x+y)^2}{(1-xy)^2} \cdot (1-xy)^2} = \frac{-yx - y(-x-y) + 1}{(1 -yx)^2\left(\frac{(x+y)^2}{(1-yx)^2} + 1\right)} = \frac{-yx - y(-x-y) + 1}{(1 -yx)^2\left(\frac{(x+y)^2 + (1 -xy)^2}{(1-yx)^2}\right)} = \frac{1 - yx + yx + y^2}{x^2 + 2xy + y^2 + 1 - 2xy + x^2y^2} = \frac{1 + y^2}{x^2 + y^2 + 1 + x^2y^2} = \frac{1 + y^2}{(x^2 + 1) + y^2(1 + x^2)} = \frac{1 + y^2}{(x^2 + 1)(1 + y^2)} = \frac{1}{x^2 + 1}$
#
# $z_{xy}'' = \frac{\partial^2z}{\partial{x}\partial{y}} = 0$
#
#
# ---

# %% [markdown]
# 6. Найти $y'$, $y''$, $y'''$ для неявной функции $y = y(x)$, заданной неявно уравнением $x^2 - xy + 2y^2 + x - y = 1$ при $x = 0$, если $y(0) = 1$

# %% [markdown]
# Найдем производную неявной функции
#
# $(x^2 -xy + 2y^2 + x - y)_x' = 1_x'$
#
# $2x - (y + xy') + 4y \cdot y' + 1 - y' = 0$
#
# $2x - y - xy' + 4y \cdot y' + 1 - y' = 0$
#
# $4y \cdot y' - y' - xy' = y - 2x - 1$
#
# $y'(4y - 1 - x) = y - 2x - 1$
#
# $y' = \frac{y - 2x - 1}{4y - x - 1}$
#
# Производная 2-ого порядка
#
# $y'' = \left(\frac{y - 2x - 1}{4y - x - 1}\right)' = \frac{u'v - uv'}{v^2} = \frac{(y - 2x - 1)'(4y - x - 1) - (y - 2x - 1)(4y - x - 1)'}{(4y - x - 1)^2} = \frac{(y' -2)(4y - x - 1) - (y -2x - 1)(4y' - 1)}{(4y - x - 1)^2} = \frac{4yy' - xy' - y' - 8y + 2x + 2 - 4yy' + 8xy' + 4y' + y - 2x - 1}{(4y - x - 1)^2} = \frac{3y' + 7xy' -7y + 1}{(4y - x - 1)^2} = \frac{y'(3 + 7x) -7y + 1}{(4y - x - 1)^2} = \frac{\frac{y - 2x - 1}{4y - x - 1}(3 + 7x) -7y + 1}{(4y - x - 1)^2} = \frac{(y - 2x - 1)(3 + 7x) - (7y + 1)(4y - x - 1)}{(4y - x - 1)^3}$
#
# Производная 3-го порядка
#
# $y''' = \left(\frac{(y - 2x - 1)(3 + 7x) - (7y + 1)(4y - x - 1)}{(4y - x - 1)^3}\right)' = \frac{((y - 2x - 1)(3 + 7x) - (7y + 1)(4y - x - 1))'((4y - x - 1)^3) - ((y - 2x - 1)(3 + 7x) - (7y + 1)(4y - x - 1)((4y - x - 1)^3)'}{(4y - x - 1)^6} = \frac{((y' - 2)(3 + 7x) + 7(y - 2x - 1) - 7y'(4y - x - 1)- (7y + 1)(4y' - 1))(4y - x - 1)^3 - 3(4y - x - 1)^2(4y' - 1)((y - 2x - 1)(3 + 7x) - (7y + 1)(4y - x - 1))}{(4y - x - 1)^6} = \frac{(-56yy' + 6y' + 14xy' -28x +14y - 12)(4y - x - 1)^3 - 3(4y - x - 1)^2(4y' - 1)(-14x^2 - 28y^2 + 14xy -12x + 6y +2)}{(4y - x - 1)^6} = \frac{((y - 2x - 1)(-56y + 14x) - (28x + 14y -12)(4y - x - 1))-3 \cdot \left(\frac{-7x - 3}{4y - x - 1}\right)(-14x^2 - 28y^2 + 14xy -12x + 6y + 2)}{(4y - x - 1)^4} = \frac{(-112y^2 + 28xy + 2x + 118y -12)(4y - x - 1)^2 + 3(7x + 3)(-14x^2 - 28y^2 + 14xy - 12x + 6y + 2)}{(4y - x - 1)^5}$
#
#
# ---

# %% [markdown]
# 7. Для функции $z = arctg\frac{y}{x}$ построить линии уровня и градиент. Сравнить их направления в точках $(1; 1), (1; -1)$

# %% [markdown]
# $z_x' = \frac{1}{1 + \frac{y^2}{x^2}} \cdot (\frac{y}{x})' = \frac{x^2}{x^2 + y^2} \cdot (-\frac{y}{x^2}) = -\frac{y}{x^2 + y^2}$
#
# $z_y' = \frac{1}{1 + \frac{y^2}{x^2}} \cdot (\frac{y}{x})'  = \frac{x^2}{x^2 + y^2} \cdot \frac{1}{x} = \frac{x}{x^2 + y^2}$
#
# Значения производных в точках
#
# $z_x'(1; 1) = -\frac{1}{2}$
#
# $z_y'(1; 1) = \frac{1}{2}$
#
# $z_x'(1; -1) = \frac{1}{2}$
#
# $z_y'(1; -1) = \frac{1}{2}$
#
# ![градиент.jpg](data:image/jpeg;base64,...)
#
# Градиенты перпендикудярны

# %%
import matplotlib.pyplot as plt

import numpy as np


def make_data():
    x = np.arange(-100, 100, 0.05)
    y = np.arange(-10, 10, 0.05)
    xgrid, ygrid = np.meshgrid(x, y)

    z = np.arctan(ygrid/xgrid)
    return xgrid, ygrid, z


if __name__ == '__main__':
    x, y, z = make_data()

    fig = plt.figure()
    axes = fig.add_subplot(projection='3d')

    axes.plot_surface(x, y, z, edgecolor='k', linewidth=0.3)
    plt.show()

# %% [markdown]
# Линии уровня

# %%
def make_data():
    x = np.arange(-10, 10, 0.05)
    y = np.arange(-10, 10, 0.05)
    xgrid, ygrid = np.meshgrid(x, y)

    z = np.arctan(ygrid/xgrid)
    return xgrid, ygrid, z


if __name__ == '__main__':
    x, y, z = make_data()

    plt.contour(x, y, z)
    plt.show()
